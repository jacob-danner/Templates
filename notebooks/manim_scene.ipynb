# %% [markdown]
# <a href="https://colab.research.google.com/github/jacob-danner/templates/blob/main/notebooks/manim_scene.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install manim. This takes about 5 minutes and requires a "restart session" button click after running.

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade

# %% [markdown]
# Install JetBrainsMono font so manim can use it.

# %%
# wget <"url"> -O <TargetFileName>
# !wget "https://download.jetbrains.com/fonts/JetBrainsMono-2.304.zip?_ga=2.153218232.1041632745.1708478443-1420032233.1708478443&_gl=1*1cjl5x3*_ga*MTQyMDAzMjIzMy4xNzA4NDc4NDQz*_ga_9J976DJZ68*MTcwODQ4OTgzNC4yLjAuMTcwODQ4OTgzNC4wLjAuMA.." -O JetBrainsMono.zip
# unzip <ZipFolder> -d <TargetDirectoryName>
# !unzip JetBrainsMono.zip -d JetBrains
# !mkdir -p ~/.fonts
# !cp -r JetBrains/* ~/.fonts
# !fc-cache -fv

# %%
from manim import *
# Out:
# Manim Community v0.18.0

# %%
# %%manim -qm -v WARNING HelloWorldScene
#
# class HelloWorldScene(Scene):
#     def construct(self):
#         text = Text('Hello World', font='JetBrains Mono', color='blue')
#         self.add(text)
